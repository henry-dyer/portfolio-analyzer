# %%
# %reset -f

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('AAPL.csv')

# %%
df['DATE'] = pd.to_datetime(df.timestamp, unit='ms').dt.date

# %%
df.head()
# Out:
#         volume  vol_weighted  price_open  price_close  price_high  price_low  \
# 0  112117471.0      125.7250     130.280       125.07    130.9000     124.17
# 1   89100633.0      126.6464     126.890       126.36    128.6557     125.08
# 2   80716808.0      126.0883     127.130       125.02    127.7700     124.76
# 3   87754715.0      128.1982     126.010       129.62    130.2900     124.89
# 4   70790813.0      131.6292     130.465       130.15    133.4100     129.89
#
#        timestamp  num_trades ticker        DATE
# 0  1672722000000     1021065   AAPL  2023-01-03
# 1  1672808400000      770042   AAPL  2023-01-04
# 2  1672894800000      665458   AAPL  2023-01-05
# 3  1672981200000      711520   AAPL  2023-01-06
# 4  1673240400000      645365   AAPL  2023-01-09

# %%
fig = px.line(df, x='DATE', y='vol_weighted')
fig.show()
